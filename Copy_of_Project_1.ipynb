# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-7925389d-6c36-47d8-a603-2711936046d1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7925389d-6c36-47d8-a603-2711936046d1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
admission = pd.read_excel("/content/Canada_Hosp1_COVID_InpatientData.xlsx", sheet_name="Data-at-admission")

# %%
admission.head()
# Out:
#    id                        reason_for_admission  age     sex ethnicity  \
# 0   1                               Fever [R50.9]   74    Male      "[]"
# 1   2                           Pneumonia [J18.9]   61  Female      "[]"
# 2   3                           Pneumonia [J18.9]   58  Female      "[]"
# 3   4  Suspected COVID-19 virus infection [U07.2]   94    Male      "[]"
# 4   5  Febrile respiratory illness [J98.9, R50.9]   91    Male      "[]"
#
#    ethnicity_other  height  weight  \
# 0              NaN     NaN     NaN
# 1              NaN   154.9    73.6
# 2              NaN     NaN     NaN
# 3              NaN   182.8    66.2
# 4              NaN     NaN     NaN
#
#                                        comorbidities  \
# 0        "[\"Hypertension\",\"Diabetes\",\"Other\"]"
# 1                     "[\"Hypertension\",\"Other\"]"
# 2                               "[\"Hypertension\"]"
# 3                     "[\"Hypertension\",\"Other\"]"
# ...

# %%
admission.shape
# Out:
# (508, 55)

# %%
admission.columns
# Out:
# Index(['id', 'reason_for_admission', 'age', 'sex', 'ethnicity',
#        'ethnicity_other', 'height', 'weight', 'comorbidities',
#        'comorbidities_other', 'received_covid_vaccine', 'covid_vaccine',
#        'medications', 'smoking_history', 'year_they_quit',
#        'previous_er_visit_within_14_days', 'admission_disposition',
#        'systolic_blood_pressure', 'diastolic_blood_pressure', 'heart_rate',
#        'respiratory_rate', 'oxygen_saturation', 'temperature', 'motor',
#        'verbal', 'eye', 'intubated', 'wbc', 'rbc', 'hemoglobin', 'hematocrit',
#        'mcv', 'mch', 'mchc', 'rdw', 'platelet_count', 'aptt_aptr', 'pt', 'alt',
#        'ast', 'serum_creatinine', 'sodium', 'potassium',
#        'total_serum_bilirubin', 'lactate', 'pao2', 'pao2_fio2', 'ph',
#        'high_senstivity_cardiac_troponin', 'esr', 'inr', 'ferritin', 'd_dimer',
#        'crp', 'hs_crp'],
#       dtype='object')

# %%
admission = admission[[
    'id',
    'age',
    'sex',
    'height',
    'weight',
    'comorbidities',
    'systolic_blood_pressure',
    'diastolic_blood_pressure',
    'heart_rate',
    'respiratory_rate',
    'oxygen_saturation',
    'temperature',
    'motor',
    'verbal',
    'eye',
    'wbc',
    'rbc',
    'hemoglobin',
    'hematocrit',
    'mcv',
    'mch',
    'mchc',
    'rdw',
    'platelet_count',
    'aptt_aptr',
    'pt',
    'alt',
    'ast',
    'serum_creatinine',
    'sodium',
    'potassium',
    'total_serum_bilirubin',
    'lactate',
    'pao2',
    'pao2_fio2',
    'ph',
    'high_senstivity_cardiac_troponin',
    'esr',
    'inr',
    'ferritin',
    'd_dimer',
    'crp',
    'hs_crp',
    'intubated'
]]

# %%
admission.shape
# Out:
# (508, 44)

# %%
hlos = pd.read_excel("/content/Canada_Hosp1_COVID_InpatientData.xlsx", sheet_name="Hospital-length-of-stay")

# %%
hlos.head()
# Out:
#    id  parent_id did_the_patient_expire_in_hospital  \
# 0   1          1                                Yes
# 1   2          2                                 No
# 2   3          3                                 No
# 3   4          4                                Yes
# 4   5          5                                Yes
#
#               reason_for_death  days_in_hospital_prior_to_expiration  \
# 0  Hospital acquired Pneumonia                                  20.0
# 1                          NaN                                   NaN
# 2                          NaN                                   NaN
# 3           COVID-19 Pneumonia                                   9.0
# 4              COVID-Pneumonia                                   9.0
#
#    hospital_length_of_stay  icu_length_of_stay  \
# 0                       21                 NaN
# 1                        5                 NaN
# 2                        7                 NaN
# ...

# %%
hlos = hlos[['parent_id', 'hospital_length_of_stay']]

# %%
hlos.head()
# Out:
#    parent_id  hospital_length_of_stay
# 0          1                       21
# 1          2                        5
# 2          3                        7
# 3          4                        9
# 4          5                        9

# %%
admission = admission.merge(
    hlos,
    left_on='id',
    right_on='parent_id'
)

# %%
admission = admission.drop(columns=['parent_id'])

# %%
admission.shape
# Out:
# (508, 45)

# %%
admission.isnull().sum()
# Out:
# id                                    0
# age                                   0
# sex                                   0
# height                              236
# weight                              150
# comorbidities                         0
# systolic_blood_pressure               0
# diastolic_blood_pressure              0
# heart_rate                            0
# respiratory_rate                      0
# oxygen_saturation                     0
# temperature                           0
# motor                                 2
# verbal                                2
# eye                                   2
# wbc                                   2
# rbc                                   2
# hemoglobin                            2
# hematocrit                            2
# mcv                                   2
# mch                                   2
# mchc                                  2
# rdw                                   2
# ...

# %%
admission = admission.drop(columns=[
    'high_senstivity_cardiac_troponin',
    'hs_crp'
])

# %%
admission.shape
# Out:
# (508, 43)

# %%
admission['aptt_aptr'] = admission['aptt_aptr'].replace('>150', '150')

admission['aptt_aptr'] = pd.to_numeric(admission['aptt_aptr'])

# %%
admission = admission.fillna(admission.mean(numeric_only=True))

# %%
admission.isnull().sum()
# Out:
# id                            0
# age                           0
# sex                           0
# height                        0
# weight                        0
# comorbidities                 0
# systolic_blood_pressure       0
# diastolic_blood_pressure      0
# heart_rate                    0
# respiratory_rate              0
# oxygen_saturation             0
# temperature                   0
# motor                         0
# verbal                        0
# eye                           0
# wbc                           0
# rbc                           0
# hemoglobin                    0
# hematocrit                    0
# mcv                           0
# mch                           0
# mchc                          0
# rdw                           0
# platelet_count                0
# aptt_aptr                     0
# pt                            0
# alt                           0
# ast                           0
# serum_creatinine              0
# ...

# %%
admission['d_dimer'] = pd.to_numeric(admission['d_dimer'], errors='coerce')

# %%
admission['d_dimer'] = admission['d_dimer'].fillna(admission['d_dimer'].mean())

# %%
admission.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
print("Number of patients:", admission.shape[0])
print("Number of columns:", admission.shape[1])
# Out:
# Number of patients: 508
# Number of columns: 43

# %%
admission.mean(numeric_only=True)
# Out:
# id                           260.877953
# age                           66.027559
# height                       166.911029
# weight                        80.265922
# systolic_blood_pressure      129.362205
# diastolic_blood_pressure      75.566929
# heart_rate                    97.397638
# respiratory_rate              24.901575
# oxygen_saturation             93.100394
# temperature                   37.768110
# motor                          5.913043
# verbal                         4.768775
# eye                            3.944664
# wbc                            8.032609
# rbc                            4.624723
# hemoglobin                   129.875494
# hematocrit                     0.395055
# mcv                           86.026877
# mch                           28.289130
# mchc                         328.581028
# rdw                           13.973123
# platelet_count               230.934783
# aptt_aptr                     31.326389
# ...

# %%
zero_columns = (admission == 0).all()

print("Number of all-zero columns:", zero_columns.sum())
# Out:
# Number of all-zero columns: 0

# %%
admission = admission.drop(columns=['id'])

# %%
admission = pd.get_dummies(admission)

# %%
admission.head()
# Out:
#    age      height     weight  systolic_blood_pressure  \
# 0   74  166.911029  80.265922                       99
# 1   61  154.900000  73.600000                      122
# 2   58  166.911029  80.265922                      109
# 3   94  182.800000  66.200000                      165
# 4   91  166.911029  80.265922                      131
#
#    diastolic_blood_pressure  heart_rate  respiratory_rate  oxygen_saturation  \
# 0                        62          85                20                 93
# 1                        77          93                36                 88
# 2                        72          73                24                 91
# 3                        71          92                16                 96
# 4                        76          60                18                 95
#
#    temperature  motor  ...  comorbidities_"[\"Obesity\"]"  \
# 0         37.5    6.0  ...                          False
# ...

# %%
X = admission.drop(columns=['hospital_length_of_stay'])

y = admission['hospital_length_of_stay']

# %%
print(X.shape)
print(y.shape)
# Out:
# (508, 179)
# (508,)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

# %%
print("Training patients:", len(X_train))
print("Testing patients:", len(X_test))
# Out:
# Training patients: 406
# Testing patients: 102

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (406, 179)
# (102, 179)

# %%
model1 = Sequential()

model1.add(Dense(32, activation='relu'))
model1.add(Dense(1))

model1.compile(optimizer='adam', loss='mse')

model1.fit(X_train, y_train, epochs=20)
# Out:
# Epoch 1/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 323.0688
# Epoch 2/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 307.1446
# Epoch 3/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 292.2565
# Epoch 4/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 279.4327
# Epoch 5/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 267.0823
# Epoch 6/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 255.6674
# Epoch 7/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 243.8482
# Epoch 8/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 233.3442
# Epoch 9/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 222.8261
# Epoch 10/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 212.7256
# Epoch 11/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 202.5225
# Epoch 12/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 193.1560
# Epoch 13/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 183.4565
# Epoch 14/20
# ...

# %%
train_mse1 = model1.evaluate(X_train, y_train)

test_mse1 = model1.evaluate(X_test, y_test)

print("Training MSE:", train_mse1)
print("Testing MSE:", test_mse1)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 126.7565
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 157.6838
# Training MSE: 126.75650024414062
# Testing MSE: 157.68380737304688

# %%
model2 = Sequential()

model2.add(Dense(64, activation='relu'))
model2.add(Dense(1))

model2.compile(optimizer='adam', loss='mse')

model2.fit(X_train, y_train, epochs=20)
# Out:
# Epoch 1/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 297.8561
# Epoch 2/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 277.9604
# Epoch 3/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 260.4722
# Epoch 4/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 243.5954
# Epoch 5/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 227.0679
# Epoch 6/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 211.4217
# Epoch 7/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 196.3092
# Epoch 8/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 180.6934
# Epoch 9/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 167.1422
# Epoch 10/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 153.0428
# Epoch 11/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 141.8023
# Epoch 12/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 130.5068
# Epoch 13/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 120.8804
# Epoch 14/20
# ...

# %%
train_mse2 = model2.evaluate(X_train, y_train)

test_mse2 = model2.evaluate(X_test, y_test)

print("Training MSE:", train_mse2)
print("Testing MSE:", test_mse2)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 85.0488
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 141.5820
# Training MSE: 85.04875183105469
# Testing MSE: 141.5819854736328

# %%
model3 = Sequential()

model3.add(Dense(64, activation='relu'))
model3.add(Dense(1))

model3.compile(optimizer='adam', loss='mse')

model3.fit(X_train, y_train, epochs=50)
# Out:
# Epoch 1/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 320.8305
# Epoch 2/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 297.8299
# Epoch 3/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 278.7416
# Epoch 4/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 260.9127
# Epoch 5/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 244.3616
# Epoch 6/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 228.8788
# Epoch 7/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 214.5065
# Epoch 8/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 200.1488
# Epoch 9/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 186.5112
# Epoch 10/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 173.1638
# Epoch 11/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 161.2949
# Epoch 12/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 149.7393
# Epoch 13/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 138.6708
# Epoch 14/50
# ...

# %%
train_mse3 = model3.evaluate(X_train, y_train)

test_mse3 = model3.evaluate(X_test, y_test)

print("Training MSE:", train_mse3)
print("Testing MSE:", test_mse3)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 53.3253
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 169.9843
# Training MSE: 53.32530212402344
# Testing MSE: 169.9843292236328

# %%
days = pd.read_excel(
    "/content/Canada_Hosp1_COVID_InpatientData.xlsx",
    sheet_name="Days-breakdown"
)

# %%
days.shape
# Out:
# (4064, 70)

# %%
days = days.merge(hlos, on='parent_id')

# %%
days['remaining_hlos'] = days['hospital_length_of_stay'] - days['day']

# %%
days[['parent_id', 'day', 'hospital_length_of_stay', 'remaining_hlos']].head()
# Out:
#    parent_id  day  hospital_length_of_stay  remaining_hlos
# 0          1    1                       21              20
# 1          1    2                       21              19
# 2          1    3                       21              18
# 3          1    4                       21              17
# 4          1    5                       21              16

# %%
days = days[days['remaining_hlos'] >= 0]

# %%
days.shape
# Out:
# (3121, 72)

# %%
days.columns
# Out:
# Index(['id', 'parent_id', 'day', 'systolic_blood_pressure',
#        'diastolic_blood_pressure', 'heart_rate', 'respiratory_rate',
#        'oxygen_saturation', 'temperature', 'highest_mean_arterial_pressure',
#        'lowest_mean_arterial_pressure', 'highest_heart_rate',
#        'lowest_heart_rate', 'highest_creatinine', 'lowest_urine_output',
#        'highest_gcs', 'lowest_gcs', 'intubated', 'highest_ph', 'lowest_ph',
#        'cardiac_arrest', 'arrested_time', 'major_cardiac_events',
#        'clinically_diagnosed_infections', 'mechanical_ventilation',
#        'number_of_vasoactive_agents', 'antiarrhythmic_therapies',
#        'renal_replacement_therapy_dialysis',
#        'cardiovascular_mechanical_support', 'fluid_balance', 'wbc', 'rbc',
#        'hemoglobin', 'hematocrit', 'platelet_count', 'aptt_aptr', 'pt', 'alt',
#        'ast', 'mch', 'mcv', 'mchc', 'rdw', 'serum_creatinine', 'sodium',
#        'potassium', 'total_serum_bilirubin', 'lactate', 'pao2', 'pao2_fio2',
# ...

# %%
days = days[[
    'parent_id',
    'day',
    'systolic_blood_pressure',
    'diastolic_blood_pressure',
    'heart_rate',
    'respiratory_rate',
    'oxygen_saturation',
    'temperature',
    'intubated',
    'wbc',
    'rbc',
    'hemoglobin',
    'hematocrit',
    'platelet_count',
    'aptt_aptr',
    'pt',
    'alt',
    'ast',
    'mch',
    'mcv',
    'mchc',
    'rdw',
    'serum_creatinine',
    'sodium',
    'potassium',
    'total_serum_bilirubin',
    'lactate',
    'pao2',
    'pao2_fio2',
    'ph',
    'esr',
    'inr',
    'ferritin',
    'd_dimer',
    'crp',
    'hs_crp',
    'remaining_hlos'
]]

# %%
days.shape
# Out:
# (3121, 37)

# %%
days.isnull().sum()
# Out:
# parent_id                      0
# day                            0
# systolic_blood_pressure       33
# diastolic_blood_pressure      33
# heart_rate                    16
# respiratory_rate              18
# oxygen_saturation             16
# temperature                   20
# intubated                      0
# wbc                         1379
# rbc                         1379
# hemoglobin                  1379
# hematocrit                  1379
# platelet_count              1384
# aptt_aptr                   2941
# pt                          2869
# alt                         2674
# ast                         2674
# mch                         1379
# mcv                         1379
# mchc                        1379
# rdw                         1379
# serum_creatinine            1108
# sodium                      1472
# potassium                   1421
# total_serum_bilirubin       2672
# lactate                     2933
# pao2                        2800
# ...

# %%
days = days.drop(columns=['hs_crp'])

# %%
for column in days.columns:
    if column != 'intubated':
        days[column] = pd.to_numeric(days[column], errors='coerce')

# %%
days = days.fillna(days.mean(numeric_only=True))

# %%
days.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
days = pd.get_dummies(days)

# %%
days.shape
# Out:
# (3121, 37)

# %%
patients = days['parent_id'].unique()

train_patients, test_patients = train_test_split(
    patients,
    test_size=0.20,
    random_state=42
)

# %%
print("Training patients:", len(train_patients))
print("Testing patients:", len(test_patients))
# Out:
# Training patients: 406
# Testing patients: 102

# %%
train_days = days[days['parent_id'].isin(train_patients)]

test_days = days[days['parent_id'].isin(test_patients)]

# %%
print(train_days.shape)
print(test_days.shape)
# Out:
# (2485, 37)
# (636, 37)

# %%
X_columns = days.columns.drop([
    'parent_id',
    'day',
    'remaining_hlos'
])

# %%
len(X_columns)
# Out:
# 34

# %%
train_days = train_days.copy()
test_days = test_days.copy()

train_days.loc[:, X_columns] = rnn_scaler.fit_transform(
    train_days[X_columns]
)

test_days.loc[:, X_columns] = rnn_scaler.transform(
    test_days[X_columns]
)

# %%
print(train_days.shape)
print(test_days.shape)
# Out:
# (2485, 37)
# (636, 37)

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
X_train_rnn = []
y_train_rnn = []

for patient in train_patients:
    patient_data = train_days[train_days['parent_id'] == patient]
    patient_data = patient_data.sort_values('day')

    X_train_rnn.append(patient_data[X_columns].values)
    y_train_rnn.append(patient_data['remaining_hlos'].iloc[-1])

# %%
X_test_rnn = []
y_test_rnn = []

for patient in test_patients:
    patient_data = test_days[test_days['parent_id'] == patient]
    patient_data = patient_data.sort_values('day')

    X_test_rnn.append(patient_data[X_columns].values)
    y_test_rnn.append(patient_data['remaining_hlos'].iloc[-1])

# %%
X_train_rnn = pad_sequences(
    X_train_rnn,
    padding='post',
    dtype='float32'
)

X_test_rnn = pad_sequences(
    X_test_rnn,
    padding='post',
    dtype='float32',
    maxlen=X_train_rnn.shape[1]
)

# %%
y_train_rnn = np.array(y_train_rnn)
y_test_rnn = np.array(y_test_rnn)

# %%
print("X train:", X_train_rnn.shape)
print("X test:", X_test_rnn.shape)

print("y train:", y_train_rnn.shape)
print("y test:", y_test_rnn.shape)
# Out:
# X train: (406, 8, 34)
# X test: (102, 8, 34)
# y train: (406,)
# y test: (102,)

# %%
from tensorflow.keras.layers import SimpleRNN, Masking

# %%
rnn1 = Sequential()

rnn1.add(Masking(mask_value=0.0))
rnn1.add(SimpleRNN(32, activation='relu'))
rnn1.add(Dense(1))

rnn1.compile(optimizer='adam', loss='mse')

# %%
rnn1.fit(
    X_train_rnn,
    y_train_rnn,
    epochs=20
)
# Out:
# Epoch 1/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 113.9677
# Epoch 2/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 103.0327
# Epoch 3/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 95.6132
# Epoch 4/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 88.1356
# Epoch 5/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 78.6637
# Epoch 6/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 73.2665
# Epoch 7/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 66.7815
# Epoch 8/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 63.1773
# Epoch 9/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 59.3205
# Epoch 10/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 56.2453
# Epoch 11/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 53.3079
# Epoch 12/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 50.6046
# Epoch 13/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 49.7217
# Epoch 14/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 46.4187
# ...

# %%
train_mse_rnn1 = rnn1.evaluate(X_train_rnn, y_train_rnn)
test_mse_rnn1 = rnn1.evaluate(X_test_rnn, y_test_rnn)

print("RNN Training MSE:", train_mse_rnn1)
print("RNN Testing MSE:", test_mse_rnn1)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 32.2329
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 70.4415
# RNN Training MSE: 32.23294448852539
# RNN Testing MSE: 70.4415283203125

# %%
rnn2 = Sequential()

rnn2.add(Masking(mask_value=0.0))
rnn2.add(SimpleRNN(64, activation='relu'))
rnn2.add(Dense(1))

rnn2.compile(optimizer='adam', loss='mse')

rnn2.fit(
    X_train_rnn,
    y_train_rnn,
    epochs=20
)
# Out:
# Epoch 1/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - loss: 97.1452
# Epoch 2/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 77.3996
# Epoch 3/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 73.7465
# Epoch 4/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 67.7987
# Epoch 5/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 63.5589
# Epoch 6/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 58.2850
# Epoch 7/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 54.5120
# Epoch 8/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 50.5031
# Epoch 9/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 47.0853
# Epoch 10/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 43.3472
# Epoch 11/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 39.7756
# Epoch 12/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 37.3562
# Epoch 13/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 33.3765
# Epoch 14/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 30.7447
# ...

# %%
train_mse_rnn2 = rnn2.evaluate(X_train_rnn, y_train_rnn)
test_mse_rnn2 = rnn2.evaluate(X_test_rnn, y_test_rnn)

print("RNN Model 2 Training MSE:", train_mse_rnn2)
print("RNN Model 2 Testing MSE:", test_mse_rnn2)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 12.2407
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 82.8660
# RNN Model 2 Training MSE: 12.240671157836914
# RNN Model 2 Testing MSE: 82.86601257324219

# %%
rnn3 = Sequential()

rnn3.add(Masking(mask_value=0.0))
rnn3.add(SimpleRNN(64, activation='relu'))
rnn3.add(Dense(1))

rnn3.compile(optimizer='adam', loss='mse')

rnn3.fit(
    X_train_rnn,
    y_train_rnn,
    epochs=50
)
# Out:
# Epoch 1/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 93.0497
# Epoch 2/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 79.2074
# Epoch 3/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 68.4358
# Epoch 4/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 63.4413
# Epoch 5/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 57.8982
# Epoch 6/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 53.6144
# Epoch 7/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 49.7304
# Epoch 8/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 46.7365
# Epoch 9/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 42.9737
# Epoch 10/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 39.4735
# Epoch 11/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 36.1227
# Epoch 12/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 32.8667
# Epoch 13/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 29.7591
# Epoch 14/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 27.5837
# ...

# %%
train_mse_rnn3 = rnn3.evaluate(X_train_rnn, y_train_rnn)
test_mse_rnn3 = rnn3.evaluate(X_test_rnn, y_test_rnn)

print("RNN Model 3 Training MSE:", train_mse_rnn3)
print("RNN Model 3 Testing MSE:", test_mse_rnn3)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.5177
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 86.1876
# RNN Model 3 Training MSE: 0.5176554918289185
# RNN Model 3 Testing MSE: 86.18756103515625
